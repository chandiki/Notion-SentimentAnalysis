# %% [markdown]
# <a href="https://colab.research.google.com/github/chandiki/Notion-SentimentAnalysis/blob/main/03_Notion_Review_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **⚙️ Process Description**

# %% [markdown]
# The preprocessing stage is conducted to transform raw user reviews from the Notion application into clean, structured, and analyzable text data. Raw text often contains inconsistencies, noise, and irrelevant elements that may reduce the accuracy of further analysis such as sentiment classification or text mining.
#
# The preprocessing pipeline consists of several sequential steps:
#
# | Step | Task | Description | Tool / Method |
# |------|------|------------|---------------|
# | 1 | Data Cleaning | Removed missing, empty, and inconsistent data to ensure dataset quality and reliability. | pandas |
# | 2 | Remove Duplicates | Eliminated duplicate review entries to avoid bias in analysis. | pandas |
# | 3 | Case Folding | Converted all text into lowercase to standardize word representation. | str.lower() |
# | 4 | Slang Normalization (Optional) | Replaced informal or abbreviated words with their standard forms to improve text clarity. | custom dictionary |
# | 5 | Noise Removal | Removed URLs, numbers, punctuation, symbols, and excessive whitespace to reduce noise. | re, string |
# | 6 | Tokenization | Split sentences into individual words (tokens) for detailed text processing. | NLTK word_tokenize |
# | 7 | Stopword Removal | Filtered out common English words with low semantic value. | NLTK stopwords |
# | 8 | Stemming | Reduced words to their root form to maintain consistency in analysis. | NLTK PorterStemmer |
# | 9 | Frequent Words Analysis (Optional) | Identified the most common words to understand dominant terms in the dataset. | Counter |
# | 10 | Rare Words Removal (Optional) | Removed infrequent words that may introduce noise in the analysis. | frequency threshold |
# | 11 | Text Reconstruction | Rejoined processed tokens into clean text for further analysis. | join() |
# | 12 | Data Export | Saved the cleaned dataset for subsequent analysis or modeling. | pandas |

# %% [markdown]
# ### **Setup & Data Loading**

# %%
# !pip install emoji
import pandas as pd
import re
import string
from collections import Counter

import nltk
import nltk
import emoji
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# Collecting emoji
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.15.0
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Load dataset
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Tugas Individu/Dataset/review_notion_raw.csv')
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                                reviewId       userName  \
# 0  acfbcf53-ca8a-40b3-a92e-d94447da864f  A Google user
# 1  ae9206ec-742a-417e-a83a-7c5536ec50f5  A Google user
# 2  9f587909-e254-4d20-a2f1-440cd989727d  A Google user
# 3  ab75d7d3-340f-40a9-aa88-23bed04f99a7  A Google user
# 4  28454e31-ae36-41d5-b1b5-11ee19f36fa7  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0    had a payment issue, the SAV solved it quickly.      5              0
# 1  Using Notion on a high-end phone, but it keeps...      1              0
# 2  I loved this app, but my documents keep going ...      3              0
# 3  powerful (All in 1). but new ke liye itna jada...      1              0
# 4  Very bad mobile experience. Everything is so s...      1              0
#
#   reviewCreatedVersion                   at replyContent repliedAt appVersion
# 0                  NaN  2026-04-29 16:35:03          NaN       NaN        NaN
# 1             0.6.3809  2026-04-29 14:15:07          NaN       NaN   0.6.3809
# 2                  NaN  2026-04-29 10:38:49          NaN       NaN        NaN
# 3                  NaN  2026-04-29 09:22:59          NaN       NaN        NaN
# 4             0.6.3803  2026-04-28 20:29:03          NaN       NaN   0.6.3803

# %%
cols_to_drop = ['reviewId', 'userName', 'userImage', 'appVersion']
df = df.drop(columns=cols_to_drop, errors='ignore')

dropped_df = pd.DataFrame({
    "column": cols_to_drop,
    "status": "dropped"
})

remaining_df = pd.DataFrame({
    "column": df.columns,
    "status": "remaining"
})

result_df = pd.concat([dropped_df, remaining_df], ignore_index=True)

display(result_df)
display(df.head(3))
# Out:
#                   column     status
# 0               reviewId    dropped
# 1               userName    dropped
# 2              userImage    dropped
# 3             appVersion    dropped
# 4                content  remaining
# 5                  score  remaining
# 6          thumbsUpCount  remaining
# 7   reviewCreatedVersion  remaining
# 8                     at  remaining
# 9           replyContent  remaining
# 10             repliedAt  remaining
#                                              content  score  thumbsUpCount  \
# 0    had a payment issue, the SAV solved it quickly.      5              0
# 1  Using Notion on a high-end phone, but it keeps...      1              0
# 2  I loved this app, but my documents keep going ...      3              0
#
#   reviewCreatedVersion                   at replyContent repliedAt
# 0                  NaN  2026-04-29 16:35:03          NaN       NaN
# 1             0.6.3809  2026-04-29 14:15:07          NaN       NaN
# 2                  NaN  2026-04-29 10:38:49          NaN       NaN

# %% [markdown]
# ### **Data Cleanig**

# %%
rows_before = len(df)

# Remove missing values
df = df.dropna(subset=['content'])
after_dropna = len(df)

# Convert to string
df['content'] = df['content'].astype(str)

# Remove empty text
df = df[df['content'].str.strip() != ""]
rows_after = len(df)

print(f"Missing removed: {rows_before - after_dropna:,} | After dropna: {after_dropna:,}")
print(f"Empty removed: {after_dropna - rows_after:,} | Remaining: {rows_after:,}")

df.head()
# Out:
# Missing removed: 0 | After dropna: 23,114
# Empty removed: 0 | Remaining: 23,114
#                                              content  score  thumbsUpCount  \
# 0    had a payment issue, the SAV solved it quickly.      5              0
# 1  Using Notion on a high-end phone, but it keeps...      1              0
# 2  I loved this app, but my documents keep going ...      3              0
# 3  powerful (All in 1). but new ke liye itna jada...      1              0
# 4  Very bad mobile experience. Everything is so s...      1              0
#
#   reviewCreatedVersion                   at replyContent repliedAt
# 0                  NaN  2026-04-29 16:35:03          NaN       NaN
# 1             0.6.3809  2026-04-29 14:15:07          NaN       NaN
# 2                  NaN  2026-04-29 10:38:49          NaN       NaN
# 3                  NaN  2026-04-29 09:22:59          NaN       NaN
# 4             0.6.3803  2026-04-28 20:29:03          NaN       NaN

# %% [markdown]
# ### **Remove Duplicates**

# %%
rows_before = len(df)
df = df.drop_duplicates(subset=['content'])
print(f"Duplicates removed: {rows_before - len(df):,} | Remaining: {len(df):,}")
df.head()
# Out:
# Duplicates removed: 1,983 | Remaining: 21,131
#                                              content  score  thumbsUpCount  \
# 0    had a payment issue, the SAV solved it quickly.      5              0
# 1  Using Notion on a high-end phone, but it keeps...      1              0
# 2  I loved this app, but my documents keep going ...      3              0
# 3  powerful (All in 1). but new ke liye itna jada...      1              0
# 4  Very bad mobile experience. Everything is so s...      1              0
#
#   reviewCreatedVersion                   at replyContent repliedAt
# 0                  NaN  2026-04-29 16:35:03          NaN       NaN
# 1             0.6.3809  2026-04-29 14:15:07          NaN       NaN
# 2                  NaN  2026-04-29 10:38:49          NaN       NaN
# 3                  NaN  2026-04-29 09:22:59          NaN       NaN
# 4             0.6.3803  2026-04-28 20:29:03          NaN       NaN

# %% [markdown]
# ### **Case Folding**

# %%
df['case_folded'] = df['content'].str.lower()
df[['content', 'case_folded']].head()
# Out:
#                                              content  \
# 0    had a payment issue, the SAV solved it quickly.
# 1  Using Notion on a high-end phone, but it keeps...
# 2  I loved this app, but my documents keep going ...
# 3  powerful (All in 1). but new ke liye itna jada...
# 4  Very bad mobile experience. Everything is so s...
#
#                                          case_folded
# 0    had a payment issue, the sav solved it quickly.
# 1  using notion on a high-end phone, but it keeps...
# 2  i loved this app, but my documents keep going ...
# 3  powerful (all in 1). but new ke liye itna jada...
# 4  very bad mobile experience. everything is so s...

# %% [markdown]
# ### **Slang Normalization**

# %%
# Define slang dictionary
slang_dict = {
    "u": "you",
    "ur": "your",
    "btw": "by the way",
    "idk": "i do not know",
    "imo": "in my opinion",
    "lol": "laugh out loud",
    "thx": "thanks",
    "pls": "please",
    "plz": "please",
    "cant": "cannot",
    "dont": "do not",
    "im": "i am",
    "ive": "i have",
    "idc": "i do not care",
    "tbh": "to be honest",
    "brb": "be right back",
    "gtg": "got to go",
    "omg": "oh my god",
    "asap": "as soon as possible",
    "wanna": "want to",
    "gonna": "going to",
    "kinda": "kind of",
    "sorta": "sort of",
    "luv": "love",
    "bff": "best friend forever",
    "fyi": "for your information",
    "rn": "right now",
    "smh": "shaking my head",
    "ikr": "i know right",
    "yolo": "you only live once",
    "gr8": "great",
    "b4": "before"
}

# Convert slang dictionary to table
slang_table = pd.DataFrame(list(slang_dict.items()), columns=['Slang', 'Formal'])

# Show slang table
slang_table.head()
# Out:
#   Slang         Formal
# 0     u            you
# 1    ur           your
# 2   btw     by the way
# 3   idk  i do not know
# 4   imo  in my opinion

# %%
# Apply normalization
def normalize_slang(text):
    words = text.split()
    normalized = [slang_dict[word] if word in slang_dict else word for word in words]
    return " ".join(normalized)

df['normalized'] = df['case_folded'].apply(normalize_slang)

df[['case_folded', 'normalized']].head()
# Out:
#                                          case_folded  \
# 0    had a payment issue, the sav solved it quickly.
# 1  using notion on a high-end phone, but it keeps...
# 2  i loved this app, but my documents keep going ...
# 3  powerful (all in 1). but new ke liye itna jada...
# 4  very bad mobile experience. everything is so s...
#
#                                           normalized
# 0    had a payment issue, the sav solved it quickly.
# 1  using notion on a high-end phone, but it keeps...
# 2  i loved this app, but my documents keep going ...
# 3  powerful (all in 1). but new ke liye itna jada...
# 4  very bad mobile experience. everything is so s...

# %% [markdown]
# ### **Noise Removal**

# %%
import re
import emoji

def clean_text(text):
    text = re.sub(r'http\S+|www\.\S+', '', text)   # remove URLs
    text = re.sub(r'\S+@\S+', '', text)            # remove emails
    text = emoji.replace_emoji(text, replace='')    # remove emojis
    text = re.sub(r'\d+', '', text)                # remove numbers
    text = re.sub(r'[^\w\s]', '', text)            # remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()       # normalize whitespace
    return text

df['clean_text'] = df['normalized'].apply(clean_text)
df[['normalized', 'clean_text']].head()
# Out:
#                                           normalized  \
# 0    had a payment issue, the sav solved it quickly.
# 1  using notion on a high-end phone, but it keeps...
# 2  i loved this app, but my documents keep going ...
# 3  powerful (all in 1). but new ke liye itna jada...
# 4  very bad mobile experience. everything is so s...
#
#                                           clean_text
# 0      had a payment issue the sav solved it quickly
# 1  using notion on a highend phone but it keeps g...
# 2  i loved this app but my documents keep going m...
# 3  powerful all in but new ke liye itna jada hard...
# 4  very bad mobile experience everything is so sl...

# %% [markdown]
# ### **Tokenization**

# %%
from nltk.tokenize import word_tokenize

df['tokens'] = df['clean_text'].apply(word_tokenize)
df['token_count'] = df['tokens'].apply(len)

print(f"Total tokens: {df['token_count'].sum():,}")
print(f"Average tokens per text: {df['token_count'].mean():.1f}")

df[['clean_text', 'tokens', 'token_count']].head()
# Out:
# Total tokens: 490,734
# Average tokens per text: 23.2
#                                           clean_text  \
# 0      had a payment issue the sav solved it quickly
# 1  using notion on a highend phone but it keeps g...
# 2  i loved this app but my documents keep going m...
# 3  powerful all in but new ke liye itna jada hard...
# 4  very bad mobile experience everything is so sl...
#
#                                               tokens  token_count
# 0  [had, a, payment, issue, the, sav, solved, it,...            9
# 1  [using, notion, on, a, highend, phone, but, it...           52
# 2  [i, loved, this, app, but, my, documents, keep...           10
# 3  [powerful, all, in, but, new, ke, liye, itna, ...           17
# 4  [very, bad, mobile, experience, everything, is...           17

# %% [markdown]
# ### **Stopword Removal**

# %%
stop_words = set(stopwords.words('english'))
def remove_stopwords(tokens):
    return [word for word in tokens if word not in stop_words]

# total tokens before removal
before = df['tokens'].apply(len).sum()

# apply stopword removal
df['filtered_tokens'] = df['tokens'].apply(remove_stopwords)

# total tokens after removal
after = df['filtered_tokens'].apply(len).sum()

print(f"Before : {before:,}")
print(f"After  : {after:,}")
print(f"Removed: {before - after:,} ({(before-after)/before*100:.1f}%)")

df[['tokens', 'filtered_tokens']].head()
# Out:
# Before : 490,734
# After  : 272,127
# Removed: 218,607 (44.5%)
#                                               tokens  \
# 0  [had, a, payment, issue, the, sav, solved, it,...
# 1  [using, notion, on, a, highend, phone, but, it...
# 2  [i, loved, this, app, but, my, documents, keep...
# 3  [powerful, all, in, but, new, ke, liye, itna, ...
# 4  [very, bad, mobile, experience, everything, is...
#
#                                      filtered_tokens
# 0             [payment, issue, sav, solved, quickly]
# 1  [using, notion, highend, phone, keeps, getting...
# 2      [loved, app, documents, keep, going, missing]
# 3  [powerful, new, ke, liye, itna, jada, hard, ha...
# 4  [bad, mobile, experience, everything, slow, ha...

# %% [markdown]
# ### **Stemming**

# %%
stemmer = PorterStemmer()
def stemming(tokens):
    return [stemmer.stem(word) for word in tokens]
df['stemmed_tokens'] = df['filtered_tokens'].apply(stemming)
df[['filtered_tokens', 'stemmed_tokens']].head()
# Out:
#                                      filtered_tokens  \
# 0             [payment, issue, sav, solved, quickly]
# 1  [using, notion, highend, phone, keeps, getting...
# 2      [loved, app, documents, keep, going, missing]
# 3  [powerful, new, ke, liye, itna, jada, hard, ha...
# 4  [bad, mobile, experience, everything, slow, ha...
#
#                                       stemmed_tokens
# 0                [payment, issu, sav, solv, quickli]
# 1  [use, notion, highend, phone, keep, get, laggi...
# 2              [love, app, document, keep, go, miss]
# 3  [power, new, ke, liy, itna, jada, hard, hai, u...
# 4  [bad, mobil, experi, everyth, slow, hard, actu...

# %% [markdown]
# ### **Frequent Words**

# %%
from collections import Counter
import pandas as pd

all_words = [word for tokens in df['stemmed_tokens'] for word in tokens]

word_freq = Counter(all_words)

freq_df = pd.DataFrame(word_freq.items(), columns=['Word', 'Frequency'])
freq_df = freq_df.sort_values(by='Frequency', ascending=False)

freq_df.head(10)
# Out:
#        Word  Frequency
# 31      app      13981
# 5       use       6058
# 6    notion       4473
# 193    note       3601
# 114    work       2782
# 118   great       2566
# 40     love       2560
# 112    like       2259
# 182    best       2187
# 67     good       2176

# %% [markdown]
# ### **Rare Words Removal**

# %%
all_stemmed = [word for tokens in df['stemmed_tokens'] for word in tokens]
stemmed_freq = Counter(all_stemmed)

RARE_THRESHOLD = 2
rare_words = {w for w, f in stemmed_freq.items() if f <= RARE_THRESHOLD}

print(f"Unique words   : {len(stemmed_freq):,}")
print(f"Rare (freq<={RARE_THRESHOLD}) : {len(rare_words):,} "
      f"({len(rare_words)/len(stemmed_freq)*100:.1f}% of vocab)")
print(f"Sample rare    : {list(rare_words)[:15]}")

# remove rare words
df['final_tokens'] = df['stemmed_tokens'].apply(
    lambda t: [w for w in t if w not in rare_words]
)

before = df['stemmed_tokens'].apply(len).sum()
after = df['final_tokens'].apply(len).sum()

print(f"Tokens before : {before:,}")
print(f"Tokens after  : {after:,}")
print(f"Removed       : {before - after:,} ({(before-after)/before*100:.1f}%)")

df[['stemmed_tokens', 'final_tokens']].head()
# Out:
# Unique words   : 14,383
# Rare (freq<=2) : 10,298 (71.6% of vocab)
# Sample rare    : ['ليست', 'unexpect', 'tol', 'apllic', 'straightup', 'creativti', 'agi', 'curso', 'misspel', 'inserta', 'appwhen', 'grammer', 'bpd', 'moveclos', 'notionsmil']
# Tokens before : 272,127
# Tokens after  : 260,185
# Removed       : 11,942 (4.4%)
#                                       stemmed_tokens  \
# 0                [payment, issu, sav, solv, quickli]
# 1  [use, notion, highend, phone, keep, get, laggi...
# 2              [love, app, document, keep, go, miss]
# 3  [power, new, ke, liy, itna, jada, hard, hai, u...
# 4  [bad, mobil, experi, everyth, slow, hard, actu...
#
#                                         final_tokens
# 0                     [payment, issu, solv, quickli]
# 1  [use, notion, highend, phone, keep, get, laggi...
# 2              [love, app, document, keep, go, miss]
# 3      [power, new, ke, hard, hai, use, bad, ui, ux]
# 4  [bad, mobil, experi, everyth, slow, hard, actu...

# %%
df['final_word_count'] = df['final_tokens'].apply(len)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Distribution
axes[0].hist(
    df['final_word_count'],
    bins=50,
    color='#FDD835',   # same style as your reference
    edgecolor='white'
)

axes[0].set_xlabel('Word Count')
axes[0].set_ylabel('Reviews')
axes[0].set_title('Distribution of Final Text Length')

# Top words
all_final = [w for tokens in df['final_tokens'] for w in tokens]
counter = Counter(all_final)

words, counts = zip(*counter.most_common(30))

axes[1].barh(
    range(30),
    counts,
    color='#D81B60',
    edgecolor='white'
)

axes[1].set_yticks(range(30))
axes[1].set_yticklabels(words)
axes[1].invert_yaxis()
axes[1].set_title('Top 20 Words (Final)')

plt.tight_layout()
plt.show()

# %%
export_columns = [
    'content',
    'score',
    'at',
    'thumbsUpCount',
    'replyContent'
]

# optional columns (only add if exist)
optional_cols = ['sentiment', 'final_text', 'final_tokens']

for col in optional_cols:
    if col in df.columns:
        export_columns.append(col)

df_export = df.loc[:, export_columns].copy()

output_file = 'notion_review_clean.csv'
df_export.to_csv(output_file, index=False)

print(f"Dataset saved: {output_file}")
print(f"Shape: {df_export.shape[0]:,} rows × {df_export.shape[1]} columns")

df_export.head(5)
# Out:
# Dataset saved: notion_review_clean.csv
# Shape: 21,131 rows × 6 columns
#                                              content  score  \
# 0    had a payment issue, the SAV solved it quickly.      5
# 1  Using Notion on a high-end phone, but it keeps...      1
# 2  I loved this app, but my documents keep going ...      3
# 3  powerful (All in 1). but new ke liye itna jada...      1
# 4  Very bad mobile experience. Everything is so s...      1
#
#                     at  thumbsUpCount replyContent  \
# 0  2026-04-29 16:35:03              0          NaN
# 1  2026-04-29 14:15:07              0          NaN
# 2  2026-04-29 10:38:49              0          NaN
# 3  2026-04-29 09:22:59              0          NaN
# 4  2026-04-28 20:29:03              0          NaN
#
#                                         final_tokens
# 0                     [payment, issu, solv, quickli]
# 1  [use, notion, highend, phone, keep, get, laggi...
# 2              [love, app, document, keep, go, miss]
# 3      [power, new, ke, hard, hai, use, bad, ui, ux]
# 4  [bad, mobil, experi, everyth, slow, hard, actu...
